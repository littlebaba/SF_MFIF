# %%
import dominate
from dominate.tags import *
import os

# %%
from PIL import Image 
from util import util

# %%
I=Image.open('image2.png')

# %%
I
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7F7DB389DD30>

# %%
l,r,o=util.blur_image(I,8,style='P')

# %%
num_div=[2,4,8,16]

# %%
for i in num_div:
    l,r,o=util.blur_image(I,i,style='C')
    l.save('tfile/%d_c_l.png'%i)
    r.save('tfile/%d_c_r.png'%i)

# %%
o
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7F7DB389DD30>

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from PIL import Image

# %%
img=Image.open(r'E:\matPro\duishuanfangduojujiao\1\fused25_cnn.png')

# %%
img=img.resize((256,256))

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x1BC84520160>

# %%
crop=img.crop((75,75,175,95))

# %%
crop
# Out:
# <PIL.Image.Image image mode=L size=100x20 at 0x1BC83DF8550>

# %%
crop.save(r'E:\paper2visio图\截图\2_cnn.png')

# %%
1//4
# Out:
# 0

# %%
range(0,2)
# Out:
# range(0, 2)

# %%
list(range(0,2))
# Out:
# [0, 1]
